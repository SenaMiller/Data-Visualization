# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
d = pd.read_csv('C:/Users/localuser/Desktop/jupyter/projects/data/ramen-ratings.csv')  
df = pd.DataFrame(data=d)
print(df)
# Out:
#       Review #           Brand  \
# 0         2580       New Touch
# 1         2579        Just Way
# 2         2578          Nissin
# 3         2577         Wei Lih
# 4         2576  Ching's Secret
# ...        ...             ...
# 2575         5           Vifon
# 2576         4         Wai Wai
# 2577         3         Wai Wai
# 2578         2         Wai Wai
# 2579         1        Westbrae
#
#                                                 Variety Style   Country Stars  \
# 0                             T's Restaurant Tantanmen    Cup     Japan  3.75
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan     1
# 2                         Cup Noodles Chicken Vegetable   Cup       USA  2.25
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan  2.75
# 4                                       Singapore Curry  Pack     India  3.75
# ...                                                 ...   ...       ...   ...
# ...

# %%
countries = set(df['Country'])
print (countries)
# Out:
# {'UK', 'Poland', 'Finland', 'Nepal', 'Hong Kong', 'Vietnam', 'Mexico', 'Japan', 'China', 'Colombia', 'Hungary', 'United States', 'Pakistan', 'Estonia', 'Sarawak', 'Holland', 'Nigeria', 'South Korea', 'Malaysia', 'Sweden', 'Australia', 'Cambodia', 'Canada', 'Dubai', 'Brazil', 'India', 'Fiji', 'Netherlands', 'USA', 'Singapore', 'Bangladesh', 'Ghana', 'Indonesia', 'Thailand', 'Taiwan', 'Germany', 'Philippines', 'Myanmar'}

# %%
stars = set(df['Stars'])
print (stars)
# Out:
# {'5.00', '3.00', '2.125', '2.75', '0.9', '3', '3.50', '3.75', '3.3', '4.00', '3.25', '3.1', '4', '3.2', '4.25', '1.1', '2.25', '2.5', '3.4', '5.0', '4.5', '1.75', '4.125', '3.8', '3.0', '4.50', '0.5', '4.0', '4.75', '2.8', '0.75', '4.3', '2.1', '3.6', '3.5', '2', '1.25', '0', '2.9', '3.7', '0.25', 'Unrated', '2.3', '2.85', '1.8', '3.125', '1.5', '1', '5', '3.65', '0.1'}

# %%
#Диаграмма рассеивания


# Prepare Data 
# Create as many colors as there are unique midwest['category']
categories = np.unique(df['Country'])
colors = [plt.cm.tab10(i/float(len(categories)-1)) for i in range(len(categories))]

# Draw Plot for Each Category
plt.figure(figsize=(16, 10), dpi= 80, facecolor='w', edgecolor='k')

for i, category in enumerate(categories):
    plt.scatter(df['Stars'].sort_values(), df['Review #'], 
                #data=df.loc[df.Country==category, :], 
                s=20, color=colors[i], label=str(category))

# Decorations
#plt.gca().set(xlim=, ylim=(0, 90000),
#              xlabel='Area', ylabel='Population')

plt.xticks(fontsize=12); plt.yticks(fontsize=12)
plt.title("Scatterplot", fontsize=22)
plt.legend(fontsize=12)    
plt.show()

# %%
#barplot

# Prepare data
x_var = 'Country'
groupby_var = 'Stars'
df_agg = df.loc[:, [x_var, groupby_var]].groupby(groupby_var)
vals = [df[x_var].values.tolist() for i, df in df_agg]

# Draw
plt.figure(figsize=(16,9), dpi= 80)
colors = [plt.cm.Spectral(i/float(len(vals)-1)) for i in range(len(vals))]
n, bins, patches = plt.hist(vals, 37, stacked=True, density=False, color=colors[:len(vals)])

# Decoration
plt.legend({group:col for group, col in zip(np.unique(df[groupby_var]).tolist(), colors[:len(vals)])})
plt.title(f"Stacked Histogram of ${x_var}$ colored by ${groupby_var}$", fontsize=22)
plt.xlabel(x_var)
plt.ylabel("Frequency")
#plt.yticks(ticks=bins[::3], labels=[round(b,1) for b in bins[::3]])
#plt.ylim(0, 100)
#plt.xticks(ticks=bins[::3], labels=[round(b,1) for b in bins[::3]])
plt.xticks(ticks=bins, labels=np.unique(df[x_var]).tolist(), rotation=90, horizontalalignment='left')
plt.show()

# %%
# Prepare Data 
# Create as many colors as there are unique midwest['category']
categories = np.unique(df['Country'])
colors = [plt.cm.tab10(i/float(len(categories)-1)) for i in range(len(categories))]

# Draw Plot for Each Category
plt.figure(figsize=(16, 10), dpi= 80, facecolor='w', edgecolor='k')

for i, category in enumerate(categories):
    plt.scatter(df['Stars'].sort_values(), df['Review #'], 
                #data=df.loc[df.Country==category, :], 
                s=20, color=colors[i], label=str(category))

# Decorations
#plt.gca().set(xlim=, ylim=(0, 90000),
#              xlabel='Area', ylabel='Population')

plt.xticks(fontsize=12); plt.yticks(fontsize=12)
plt.title("Scatterplot", fontsize=22)
plt.legend(fontsize=12)    
plt.show()
